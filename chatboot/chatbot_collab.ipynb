# %%
### CREATE VIRTUAL DISPLAY ###
# !apt-get install -y xvfb # Install X Virtual Frame Buffer
import os
os.system('Xvfb :1 -screen 0 1600x1200x16  &')    # create virtual display with size 1600x1200 and 16 bit color. Color can be changed to 24 or 8
os.environ['DISPLAY']=':1.0'    # tell X clients to use our virtual DISPLAY :1.0.s
# Out:
# 'apt-get' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %% [markdown]
# libraries

# %%
import tensorflow as tf
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\hp\Desktop\chatbot_collab.ipynb Cell 3' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/chatbot_collab.ipynb#ch0000002?line=7'>8</a> import pickle
#      <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/chatbot_collab.ipynb#ch0000002?line=9'>10</a> import numpy as np
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/chatbot_collab.ipynb#ch0000002?line=10'>11</a> from keras.models import Sequential
#      <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/chatbot_collab.ipynb#ch0000002?line=11'>12</a> from keras.layers import Dense, Activation, Dropout
#      <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/chatbot_collab.ipynb#ch0000002?line=12'>13</a> from tensorflow.keras.optimizers import SGD
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__init__.py:24, in <module>
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/__init__.py?line=20'>21</a> from tensorflow.python import tf2
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/__init__.py?line=21'>22</a> from keras import distribute
# ---> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/__init__.py?line=23'>24</a> from keras import models
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/__init__.py?line=25'>26</a> from keras.engine.input_layer import Input
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/__init__.py?line=26'>27</a> from keras.engine.sequential import Sequential
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\models\__init__.py:18, in <module>
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/models/__init__.py?line=14'>15</a> """Keras models API."""
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/models/__init__.py?line=15'>16</a> # pylint: disable=g-bad-import-order
# ---> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/models/__init__.py?line=17'>18</a> from keras.engine.functional import Functional
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/models/__init__.py?line=18'>19</a> from keras.engine.sequential import Sequential
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/models/__init__.py?line=19'>20</a> from keras.engine.training import Model
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\functional.py:24, in <module>
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/engine/functional.py?line=21'>22</a> import warnings
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/engine/functional.py?line=22'>23</a> from keras import backend
# ---> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/engine/functional.py?line=23'>24</a> from keras.dtensor import layout_map as layout_map_lib
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/engine/functional.py?line=24'>25</a> from keras.engine import base_layer
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/engine/functional.py?line=25'>26</a> from keras.engine import base_layer_utils
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\dtensor\__init__.py:22, in <module>
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/dtensor/__init__.py?line=19'>20</a> # Conditional import the dtensor API, since it is currently broken in OSS.
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/dtensor/__init__.py?line=20'>21</a> if _DTENSOR_API_ENABLED:
# ---> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/dtensor/__init__.py?line=21'>22</a>   from tensorflow.compat.v2.experimental import dtensor as dtensor_api  # pylint: disable=g-import-not-at-top
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/dtensor/__init__.py?line=22'>23</a> else:
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/dtensor/__init__.py?line=23'>24</a>   # Leave it with a placeholder, so that the import line from other python file
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/dtensor/__init__.py?line=24'>25</a>   # will not break.
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/keras/dtensor/__init__.py?line=25'>26</a>   dtensor_api = None
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\_api\v2\compat\v2\experimental\dtensor\__init__.py:8, in <module>
#       <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/_api/v2/compat/v2/experimental/dtensor/__init__.py?line=2'>3</a> """Public API for tf.experimental.dtensor namespace.
#       <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/_api/v2/compat/v2/experimental/dtensor/__init__.py?line=3'>4</a> """
#       <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/_api/v2/compat/v2/experimental/dtensor/__init__.py?line=5'>6</a> import sys as _sys
# ----> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/_api/v2/compat/v2/experimental/dtensor/__init__.py?line=7'>8</a> from tensorflow.dtensor.python.api import call_with_layout
#       <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/_api/v2/compat/v2/experimental/dtensor/__init__.py?line=8'>9</a> from tensorflow.dtensor.python.api import check_layout
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/_api/v2/compat/v2/experimental/dtensor/__init__.py?line=9'>10</a> from tensorflow.dtensor.python.api import client_id
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\dtensor\python\__init__.py:18, in <module>
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/__init__.py?line=14'>15</a> """DTensor Python API."""
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/__init__.py?line=16'>17</a> from tensorflow.dtensor.python import gen_dtensor_ops as ops
# ---> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/__init__.py?line=17'>18</a> from tensorflow.dtensor.python import mesh_util
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/__init__.py?line=18'>19</a> from tensorflow.dtensor.python import tpu_util
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/__init__.py?line=20'>21</a> from tensorflow.dtensor.python.api import call_with_layout
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\dtensor\python\mesh_util.py:21, in <module>
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/mesh_util.py?line=17'>18</a> from absl import logging
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/mesh_util.py?line=18'>19</a> import numpy as np
# ---> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/mesh_util.py?line=20'>21</a> from tensorflow.dtensor.python import api
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/mesh_util.py?line=21'>22</a> from tensorflow.dtensor.python import layout
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/mesh_util.py?line=22'>23</a> from tensorflow.dtensor.python import multi_client_util
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\dtensor\python\api.py:22, in <module>
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/api.py?line=18'>19</a> import threading
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/api.py?line=19'>20</a> from typing import Any, Callable, List, Optional, Sequence, Union
# ---> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/api.py?line=21'>22</a> from tensorflow.dtensor.python import dtensor_device
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/api.py?line=22'>23</a> from tensorflow.dtensor.python import gen_dtensor_ops
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/api.py?line=23'>24</a> from tensorflow.dtensor.python import layout as layout_lib
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\dtensor\python\dtensor_device.py:28, in <module>
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/dtensor_device.py?line=25'>26</a> from tensorflow.dtensor.python import gen_dtensor_ops
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/dtensor_device.py?line=26'>27</a> from tensorflow.dtensor.python import layout as layout_lib
# ---> <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/dtensor_device.py?line=27'>28</a> from tensorflow.python import _pywrap_dtensor_device
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/dtensor_device.py?line=28'>29</a> from tensorflow.python.eager import context
#      <a href='file:///c%3A/Users/hp/AppData/Local/Programs/Python/Python310/lib/site-packages/tensorflow/dtensor/python/dtensor_device.py?line=29'>30</a> from tensorflow.python.eager import core
#
# ImportError: cannot import name '_pywrap_dtensor_device' from 'tensorflow.python' (c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py)

# %% [markdown]
# Initializing Chatbot Training

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('job_intents.json').read()
intents = json.loads(data_file)

# %% [markdown]
# # Nouvelle section

# %% [markdown]
# words

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")


print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 53 documents
# 7 classes ['goodbye', 'greeting', 'name', 'options', 'south_africa_facts', 'south_africa_info', 'thanks']
# 51 unique lemmatized words ["'s", ',', 'about', 'africa', 'anyone', 'are', 'awesome', 'bye', 'can', 'day', 'do', 'ekse', 'fact', 'for', 'give', 'good', 'goodbye', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hola', 'how', 'interesting', 'is', 'know', 'later', 'me', 'more', 'name', 'ok', 'purpose', 'sa', 'see', 'some', 'something', 'south', 'tell', 'thank', 'thanks', 'that', 'there', 'ungubani', 'what', 'whats', 'who', 'you', 'your', 'yourself']

# %% [markdown]
# Building the Deep Learning Model

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 11/11 [==============================] - 1s 2ms/step - loss: 1.9417 - accuracy: 0.2264
# Epoch 2/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8753 - accuracy: 0.2642
# Epoch 3/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7568 - accuracy: 0.2642
# Epoch 4/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6687 - accuracy: 0.3396
# Epoch 5/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.4823 - accuracy: 0.5660
# Epoch 6/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.4818 - accuracy: 0.3962
# Epoch 7/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.4493 - accuracy: 0.5472
# Epoch 8/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.2735 - accuracy: 0.5849
# Epoch 9/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1973 - accuracy: 0.6415
# Epoch 10/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.0784 - accuracy: 0.5660
# Epoch 11/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.0929 - accuracy: 0.5660
# Epoch 12/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.9832 - accuracy: 0.6981
# Epoch 13/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8236 - accuracy: 0.7358
# Epoch 14/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8138 - accuracy: 0.8113
# Epoch 15/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7074 - accuracy: 0.8113
# Epoch 16/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.7925
# Epoch 17/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6086 - accuracy: 0.8113
# Epoch 18/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.8113
# Epoch 19/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4996 - accuracy: 0.8679
# Epoch 20/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4693 - accuracy: 0.8868
# Epoch 21/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.8679
# Epoch 22/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.3905 - accuracy: 0.9245
# Epoch 23/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8679
# Epoch 24/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4162 - accuracy: 0.8868
# Epoch 25/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.9245
# Epoch 26/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3113 - accuracy: 0.9245
# Epoch 27/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2707 - accuracy: 0.9434
# Epoch 28/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8868
# Epoch 29/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.9623
# Epoch 30/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.3167 - accuracy: 0.9245
# Epoch 31/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2724 - accuracy: 0.9434
# Epoch 32/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9623
# Epoch 33/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2571 - accuracy: 0.9057
# Epoch 34/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2624 - accuracy: 0.9434
# Epoch 35/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2389 - accuracy: 0.9434
# Epoch 36/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2704 - accuracy: 0.9245
# Epoch 37/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2035 - accuracy: 0.9434
# Epoch 38/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2011 - accuracy: 0.9434
# Epoch 39/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.9811
# Epoch 40/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 1.0000
# Epoch 41/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2708 - accuracy: 0.9623
# Epoch 42/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.9623
# Epoch 43/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1421 - accuracy: 0.9623
# Epoch 44/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.9623
# Epoch 45/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9811
# Epoch 46/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.9811
# Epoch 47/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.9811
# Epoch 48/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1604 - accuracy: 0.9434
# Epoch 49/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1638 - accuracy: 0.9623
# Epoch 50/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1271 - accuracy: 0.9623
# Epoch 51/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1515 - accuracy: 0.9811
# Epoch 52/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1175 - accuracy: 0.9811
# Epoch 53/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1270 - accuracy: 0.9434
# Epoch 54/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9811
# Epoch 55/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9623
# Epoch 56/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0930 - accuracy: 1.0000
# Epoch 57/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.9811
# Epoch 58/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9811
# Epoch 59/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9811
# Epoch 60/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9434
# Epoch 61/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0606 - accuracy: 0.9811
# Epoch 62/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9811
# Epoch 63/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1378 - accuracy: 0.9623
# Epoch 64/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 65/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9811
# Epoch 66/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9811
# Epoch 67/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 1.0000
# Epoch 68/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 0.9811
# Epoch 69/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0762 - accuracy: 0.9811
# Epoch 70/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9811
# Epoch 71/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9811
# Epoch 72/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 0.9811
# Epoch 73/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 0.9811
# Epoch 74/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 1.0000
# Epoch 75/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 76/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0499 - accuracy: 1.0000
# Epoch 77/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9811
# Epoch 78/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 79/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9811
# Epoch 80/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 81/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0465 - accuracy: 0.9811
# Epoch 82/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0941 - accuracy: 0.9811
# Epoch 83/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0918 - accuracy: 0.9811
# Epoch 84/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 85/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9623
# Epoch 86/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9811
# Epoch 87/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 88/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 89/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9811
# Epoch 90/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 91/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 1.0000
# Epoch 92/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 93/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 94/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 95/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 96/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.9623
# Epoch 97/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 98/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 99/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 100/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 101/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 102/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 103/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 104/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 105/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 106/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9811
# Epoch 107/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 108/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0486 - accuracy: 0.9811
# Epoch 109/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 110/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 111/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 112/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 113/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9811
# Epoch 114/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 0.9811
# Epoch 115/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 116/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 117/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 118/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 119/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 120/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9811
# Epoch 121/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9811
# Epoch 122/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0677 - accuracy: 0.9811
# Epoch 123/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 124/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9811
# Epoch 125/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 126/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 0.9811
# Epoch 127/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0488 - accuracy: 0.9623
# Epoch 128/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 129/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 130/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 131/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 132/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 133/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9623
# Epoch 134/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 135/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 136/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 137/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 138/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 139/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 140/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 141/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 142/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 143/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 144/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 145/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 146/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 147/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 148/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 149/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 150/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 151/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 152/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 153/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 154/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 155/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 156/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 157/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9623
# Epoch 158/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 159/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 160/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 161/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 162/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 163/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 164/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 165/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.9811
# Epoch 166/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 167/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 168/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 169/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 170/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 171/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 172/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 173/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 174/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9811
# Epoch 175/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 176/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 177/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 178/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 179/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 180/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 0.9811
# Epoch 181/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 182/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 183/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 184/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9811
# Epoch 185/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 186/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 187/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 188/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 189/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9811
# Epoch 190/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9811
# Epoch 191/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 192/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 193/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 194/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 195/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9623
# Epoch 196/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 197/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 198/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 199/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 200/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 0.9811
# model created

# %% [markdown]
# Building Chatbot GUI

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('job_intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter

import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
